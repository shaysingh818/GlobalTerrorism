# %%
import spacy
from spacy import displacy

NER = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-f949db510ee5> in <module>
#       2 from spacy import displacy
#       3
# ----> 4 NER = spacy.load("en_core_web_sm")
#
# ~/.local/lib/python3.8/site-packages/spacy/__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~/.local/lib/python3.8/site-packages/spacy/util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# ...

# %%
# Out:
# [nltk_data] Downloading package punkt to /home/dread/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dread/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
df = pd.read_csv('../cve.csv').dropna()
df.head()
# Out:
#          Unnamed: 0             mod_date             pub_date  cvss  cwe_code  \
# 138   CVE-2019-2211  2019-11-14 21:36:00  2019-11-13 18:15:00   7.8        89
# 139   CVE-2019-2212  2019-11-14 21:30:00  2019-11-13 18:15:00   4.9       200
# 140   CVE-2019-2213  2019-11-14 21:24:00  2019-11-13 18:15:00   6.9       416
# 149   CVE-2019-2214  2019-11-14 21:19:00  2019-11-13 18:15:00   7.2       269
# 150  CVE-2019-18793  2019-11-14 21:14:00  2019-11-13 20:15:00   4.3        79
#
#                                               cwe_name  \
# 138   Improper Neutralization of Special Elements u...
# 139                               Information Exposure
# 140                                     Use After Free
# 149                      Improper Privilege Management
# 150   Improper Neutralization of Input During Web P...
#
#                                                summary access_authentication  \
# 138  In createProjectionMapForQuery of TvProvider.j...                  NONE
# ...

# %%
my_data = pd.DataFrame(df, columns=['summary', 'cwe_name']).dropna()
my_data = my_data[my_data["cwe_name"] == " Information Exposure"]
my_data.head()
# Out:
#                                                summary               cwe_name
# 139  In poisson_distribution of random, there is an...   Information Exposure
# 669  ** DISPUTED ** On Coldcard MK1 and MK2 devices...   Information Exposure
# 688  A vulnerability was discovered in oVirt 4.1.x ...   Information Exposure
# 690  In ovirt-engine 4.1, if a host was provisioned...   Information Exposure
# 692  The REST API in oVirt 3.4.0 and earlier stores...   Information Exposure
