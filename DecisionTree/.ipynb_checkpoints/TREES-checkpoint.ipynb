# %%
from sklearn import tree
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data.csv', encoding="latin-1")
df = df.head(500)
df.head()
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
inputs = df.filter(["attacktype1_txt", "weaptype1_txt", "location"])
inputs
# Out:
#                     attacktype1_txt weaptype1_txt                     location
# 0                     Assassination       Unknown                          NaN
# 1       Hostage Taking (Kidnapping)       Unknown                          NaN
# 2                     Assassination       Unknown                          NaN
# 3                 Bombing/Explosion    Explosives                          NaN
# 4    Facility/Infrastructure Attack    Incendiary                          NaN
# ..                              ...           ...                          ...
# 495               Bombing/Explosion    Explosives                          NaN
# 496                   Assassination    Explosives                          NaN
# 497               Bombing/Explosion    Explosives                          NaN
# 498               Bombing/Explosion    Explosives         1707 E. North Avenue
# 499               Bombing/Explosion    Explosives  Thrown in front of building
#
# [500 rows x 3 columns]

# %%
target = df["gname"]
target
# Out:
# 0                                  MANO-D
# 1      23rd of September Communist League
# 2                                 Unknown
# 3                                 Unknown
# 4                                 Unknown
#                       ...
# 495                               Unknown
# 496                   Tupamaros (Uruguay)
# 497           Irish Republican Army (IRA)
# 498                   Left-Wing Militants
# 499                   Left-Wing Militants
# Name: gname, Length: 500, dtype: object

# %%
attack_type = LabelEncoder()
weapon_type = LabelEncoder()
location_type = LabelEncoder()
inputs["attack_n"] = attack_type.fit_transform(inputs["attacktype1_txt"])
inputs["weapontype_n"] = attack_type.fit_transform(inputs["weaptype1_txt"])
inputs["location_n"] = attack_type.fit_transform(inputs["location"])
inputs
# Out:
#                     attacktype1_txt weaptype1_txt  \
# 0                     Assassination       Unknown
# 1       Hostage Taking (Kidnapping)       Unknown
# 2                     Assassination       Unknown
# 3                 Bombing/Explosion    Explosives
# 4    Facility/Infrastructure Attack    Incendiary
# ..                              ...           ...
# 495               Bombing/Explosion    Explosives
# 496                   Assassination    Explosives
# 497               Bombing/Explosion    Explosives
# 498               Bombing/Explosion    Explosives
# 499               Bombing/Explosion    Explosives
#
#                         location  attack_n  weapontype_n  location_n
# 0                            NaN         1             6         142
# 1                            NaN         6             6         142
# 2                            NaN         1             6         142
# 3                            NaN         2             1         142
# ...

# %%
inputs_n = inputs.drop(['attacktype1_txt', 'weaptype1_txt', 'location'], axis='columns')
inputs_n
# Out:
#      attack_n  weapontype_n  location_n
# 0           1             6         142
# 1           6             6         142
# 2           1             6         142
# 3           2             1         142
# 4           3             3         142
# ..        ...           ...         ...
# 495         2             1         142
# 496         1             1         142
# 497         2             1         142
# 498         2             1           5
# 499         2             1         119
#
# [500 rows x 3 columns]

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n, target)
# Out:
# 0.558

# %%
fig = plt.figure(figsize(25, 20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9dd30125b794> in <module>
# ----> 1 fig = plt.figure(figsize(25, 20))
#
# NameError: name 'plt' is not defined
